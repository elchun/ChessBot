# %%
from generate_chess_data import ChessDataGen
from tqdm import tqdm
# import multiprocess
import numpy as np

# %%
data_station = ChessDataGen()
# data_station.show_label_image()
data_station.show_rgb_image()
# Out:
# {2: 'a1RW', 3: 'b1NW', 4: 'c1BW', 5: 'd1QW', 6: 'e1KW', 7: 'f1BW', 8: 'g1NW', 9: 'h1RW', 10: 'a2PW', 11: 'b2PW', 12: 'c2PW', 13: 'd2PW', 14: 'e2PW', 15: 'f2PW', 16: 'g2PW', 17: 'h2PW', 18: 'a8RB', 19: 'b8NB', 20: 'c8BB', 21: 'd8QB', 22: 'e8KB', 23: 'f8BB', 24: 'g8NB', 25: 'h8RB', 26: 'a7PB', 27: 'b7PB', 28: 'c7PB', 29: 'd7PB', 30: 'e7PB', 31: 'f7PB', 32: 'g7PB', 33: 'h7PB'}

# %%
data_station = ChessDataGen()
data_station.show_rgb_image()
# Out:
# {2: 'a1RW', 3: 'b1NW', 4: 'c1BW', 5: 'd1QW', 6: 'e1KW', 7: 'f1BW', 8: 'g1NW', 9: 'h1RW', 10: 'a2PW', 11: 'b2PW', 12: 'c2PW', 13: 'd2PW', 14: 'e2PW', 15: 'f2PW', 16: 'g2PW', 17: 'h2PW', 18: 'a8RB', 19: 'b8NB', 20: 'c8BB', 21: 'd8QB', 22: 'e8KB', 23: 'f8BB', 24: 'g8NB', 25: 'h8RB', 26: 'a7PB', 27: 'b7PB', 28: 'c7PB', 29: 'd7PB', 30: 'e7PB', 31: 'f7PB', 32: 'g7PB', 33: 'h7PB'}

# %%
i = 'start'
num_pieces = np.random.randint(1, 33)
fn = f'temp_data/board_{i}'
# fn = f'temp_data/test'
data_station.save_rgb_image(fn + '.png')
data_station.save_label_mask(fn + '_mask')
data_station.show_rgb_image()
data_station.show_label_image()
# Out:
# Num Unique values:  34

# %%
data_station.save_instance_id_to_class_name()
for i in tqdm(range(1000, 1010)):
    num_pieces = np.random.randint(1, 33)
    fn = f'temp_data/board_{i:05}'
    # fn = f'temp_data/test'
    data_station.set_arbitrary_board(num_pieces=num_pieces)
    data_station.save_rgb_image(fn + '.png')
    data_station.save_label_mask(fn + '_mask')
data_station.show_rgb_image()
data_station.show_label_image()
# Out:
#  45%|████▍     | 449/1000 [01:25<01:44,  5.25it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /opt/homebrew/lib/python3.10/site-packages/PIL/ImageFile.py:503, in _save(im, fp, tile, bufsize)
#     502 try:
# --> 503     fh = fp.fileno()
#     504     fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [4], line 7
#       5     # fn = f'temp_data/test'
#       6     data_station.set_arbitrary_board(num_pieces=num_pieces)
# ----> 7     data_station.save_rgb_image(fn + '.png')
#       8     data_station.save_label_mask(fn + '_mask')
#       9 data_station.show_rgb_image()
#
# File ~/Documents/6_4210/ChessBot/src/generate_chess_data.py:147, in ChessDataGen.save_rgb_image(self, fn)
# ...

# %%
data_station.show_rgb_image()

# %%
# pool = multiprocess.Pool(1)
# def f(i):
#     print(i, end='')
#     data_station.set_arbitrary_board()
#     data_station.save_rgb_image('`')

# # def f(i):
# #     print(i, end='')

# num_images = 100
    
# list(tqdm(pool.imap(f, range(num_images)), total=num_images))
# pool.close()
# pool.join()
