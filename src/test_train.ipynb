# %%
from generate_chess_data import ChessDataGen
from tqdm import tqdm
import multiprocess

# %%
data_station = ChessDataGen()
data_station.show_label_image()
# Out:
# {2: 'a1RW', 3: 'b1NW', 4: 'c1BW', 5: 'd1QW', 6: 'e1KW', 7: 'f1BW', 8: 'g1NW', 9: 'h1RW', 10: 'a2PW', 11: 'b2PW', 12: 'c2PW', 13: 'd2PW', 14: 'e2PW', 15: 'f2PW', 16: 'g2PW', 17: 'h2PW', 18: 'a8RB', 19: 'b8NB', 20: 'c8BB', 21: 'd8QB', 22: 'e8KB', 23: 'f8BB', 24: 'g8NB', 25: 'h8RB', 26: 'a7PB', 27: 'b7PB', 28: 'c7PB', 29: 'd7PB', 30: 'e7PB', 31: 'f7PB', 32: 'g7PB', 33: 'h7PB'}

# %%
data_station = ChessDataGen()
data_station.show_rgb_image()
# Out:
# {2: 'a1RW', 3: 'b1NW', 4: 'c1BW', 5: 'd1QW', 6: 'e1KW', 7: 'f1BW', 8: 'g1NW', 9: 'h1RW', 10: 'a2PW', 11: 'b2PW', 12: 'c2PW', 13: 'd2PW', 14: 'e2PW', 15: 'f2PW', 16: 'g2PW', 17: 'h2PW', 18: 'a8RB', 19: 'b8NB', 20: 'c8BB', 21: 'd8QB', 22: 'e8KB', 23: 'f8BB', 24: 'g8NB', 25: 'h8RB', 26: 'a7PB', 27: 'b7PB', 28: 'c7PB', 29: 'd7PB', 30: 'e7PB', 31: 'f7PB', 32: 'g7PB', 33: 'h7PB'}

# %%
for i in tqdm(range(10)):
    data_station.set_arbitrary_board()
    data_station.save_rgb_image()
    data_station.save_label_mask()
data_station.show_rgb_image()
data_station.show_label_image()
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/lib/python3.10/site-packages/PIL/Image.py:2992, in fromarray(obj, mode)
#    2991 try:
# -> 2992     mode, rawmode = _fromarray_typemap[typekey]
#    2993 except KeyError as e:
#
# KeyError: ((1, 1, 3), '<f8')
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In [3], line 5
#       3     data_station.save_rgb_image()
#       4     data_station.save_label_mask()
# ----> 5     data_station.save_label_mask_png()
#       6 data_station.show_rgb_image()
#
# File ~/Documents/6_4210/ChessBot/src/generate_chess_data.py:146, in ChessDataGen.save_label_mask_png(self, fn)
#     139 """
#     140 JUST FOR FUN (NOT USEFUL!!!)
#     141
#     142 Args:
#     143     fn (str, optional): _description_. Defaults to 'temp_data/mask.png'.
#     144 """
#     145 label_image = self.station.GetOutputPort('camera_label_image').Eval(self.station_context)
# --> 146 im = Image.fromarray(colorize_labels(label_image.data))
#     147 im.save(fn)
#
# File /opt/homebrew/lib/python3.10/site-packages/PIL/Image.py:2994, in fromarray(obj, mode)
#    2992         mode, rawmode = _fromarray_typemap[typekey]
#    2993     except KeyError as e:
# -> 2994         raise TypeError("Cannot handle this data type: %s, %s" % typekey) from e
#    2995 else:
#    2996     rawmode = mode
#
# TypeError: Cannot handle this data type: (1, 1, 3), <f8

# %%
# pool = multiprocess.Pool(1)
# def f(i):
#     print(i, end='')
#     data_station.set_arbitrary_board()
#     data_station.save_rgb_image('`')

# # def f(i):
# #     print(i, end='')

# num_images = 100
    
# list(tqdm(pool.imap(f, range(num_images)), total=num_images))
# pool.close()
# pool.join()
# Out:
# 0
# 2022-12-01 23:16:24.039 Python[17857:845560] *** Assertion failure in CGColorSpaceRef  _Nonnull copy_surface_colorspace(CGSConnectionID, CGSWindowID, CGSSurfaceID)(), NSCGLSurface.m:111
#   0%|          | 0/100 [00:00<?, ?it/s]
# 1
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/Users/elchun/Documents/6_4210/env/lib/python3.10/site-packages/multiprocess/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/var/folders/ql/vr72nq9d1kn1fvjh3vrhft600000gn/T/ipykernel_17141/310446985.py", line 5, in f
#     data_station.save_rgb_image()
#   File "/Users/elchun/Documents/6_4210/ChessBot/src/generate_chess_data.py", line 123, in save_rgb_image
#     color_image = self.station.GetOutputPort("camera_rgb_image").Eval(self.station_context)
# RuntimeError: Caught an unknown exception!
# """
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In [24], line 12
#       7 # def f(i):
#       8 #     print(i, end='')
#      10 num_images = 100
# ---> 12 list(tqdm(pool.imap(f, range(num_images)), total=num_images))
#      13 pool.close()
#      14 pool.join()
#
# File ~/Documents/6_4210/env/lib/python3.10/site-packages/tqdm/std.py:1195, in tqdm.__iter__(self)
#    1192 time = self._time
#    1194 try:
# -> 1195     for obj in iterable:
#    1196         yield obj
#    1197         # Update and possibly print the progressbar.
#    1198         # Note: does not call self.update(1) for speed optimisation.
#
# File ~/Documents/6_4210/env/lib/python3.10/site-packages/multiprocess/pool.py:873, in IMapIterator.next(self, timeout)
#     871 if success:
#     872     return value
# --> 873 raise value
#
# RuntimeError: Caught an unknown exception!
