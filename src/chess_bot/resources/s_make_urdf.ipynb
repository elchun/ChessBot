# %%
import numpy as np

# %%
bishop_prop = """
Mass	0.05 kg
Volume	3.489E-05 m^3
Density	1425.00 kg / m^3
Area	0.009 m^2
World X,Y,Z	0.00 m, 0.00 m, 0.00 m
Center of Mass	-5.732E-08 m, 0.00 m, 0.029 m
Bounding Box
	Length	0.041 m
	Width	0.041 m
	Height	0.092 m
Moment of Inertia at Center of Mass   (kg m^2)
	Ixx	3.741E-05
	Ixy	0.00
	Ixz	1.303E-10
	Iyx	0.00
	Iyy	3.736E-05
	Iyz	-2.403E-07
	Izx	1.303E-10
	Izy	-2.403E-07
	Izz	5.944E-06
Moment of Inertia at Origin   (kg m^2)
	Ixx	7.970E-05
	Ixy	0.00
	Ixz	2.134E-10
	Iyx	0.00
	Iyy	7.965E-05
	Iyz	-3.974E-07
	Izx	2.134E-10
	Izy	-3.974E-07
	Izz	5.944E-06
"""

king_prop = """
Mass	0.066 kg
Volume	4.618E-05 m^3
Density	1425.00 kg / m^3
Area	0.011 m^2
World X,Y,Z	0.00 m, 0.00 m, 0.00 m
Center of Mass	-1.601E-08 m, -1.691E-08 m, 0.036 m
Bounding Box
    Length	0.043 m
    Width	0.043 m
    Height	0.113 m
Moment of Inertia at Center of Mass   (kg m^2)
    Ixx	7.320E-05
    Ixy	0.00
    Ixz	0.00
    Iyx	0.00
    Iyy	7.321E-05
    Iyz	0.00
    Izx	0.00
    Izy	0.00
    Izz	8.252E-06
Moment of Inertia at Origin   (kg m^2)
    Ixx	0.00
    Ixy	0.00
    Ixz	0.00
    Iyx	0.00
    Iyy	0.00
    Iyz	0.00
    Izx	0.00
    Izy	0.00
    Izz	8.252E-06
"""

knight_prop = """
Mass	0.071 kg
Volume	4.996E-05 m^3
Density	1425.00 kg / m^3
Area	0.01 m^2
World X,Y,Z	0.00 m, 0.00 m, 0.00 m
Center of Mass	-1.389E-06 m, 0.003 m, 0.029 m
Bounding Box
    Length	0.043 m
    Width	0.046 m
    Height	0.083 m
Moment of Inertia at Center of Mass   (kg m^2)
    Ixx	3.744E-05
    Ixy	-4.645E-10
    Ixz	4.445E-10
    Iyx	-4.645E-10
    Iyy	3.474E-05
    Iyz	-4.037E-06
    Izx	4.445E-10
    Izy	-4.037E-06
    Izz	1.079E-05
Moment of Inertia at Origin   (kg m^2)
    Ixx	9.762E-05
    Ixy	-1.786E-10
    Ixz	3.305E-09
    Iyx	-1.786E-10
    Iyy	9.433E-05
    Iyz	-9.992E-06
    Izx	3.305E-09
    Izy	-9.992E-06
    Izz	1.139E-05
"""

pawn_prop = """
Mass	0.032 kg
Volume	2.268E-05 m^3
Density	1425.00 kg / m^3
Area	0.006 m^2
World X,Y,Z	0.00 m, 0.00 m, 0.00 m
Center of Mass	-3.677E-07 m, 1.233E-07 m, 0.021 m
Bounding Box
    Length	0.039 m
    Width	0.039 m
    Height	0.062 m
Moment of Inertia at Center of Mass   (kg m^2)
    Ixx	1.393E-05
    Ixy	0.00
    Ixz	3.527E-10
    Iyx	0.00
    Iyy	1.392E-05
    Iyz	-1.150E-10
    Izx	3.527E-10
    Izy	-1.150E-10
    Izz	3.265E-06
Moment of Inertia at Origin   (kg m^2)
    Ixx	2.876E-05
    Ixy	0.00
    Ixz	6.073E-10
    Iyx	0.00
    Iyy	2.876E-05
    Iyz	-2.004E-10
    Izx	6.073E-10
    Izy	-2.004E-10
    Izz	3.265E-06
"""

queen_prop = """
Mass	0.064 kg
Volume	4.469E-05 m^3
Density	1425.00 kg / m^3
Area	0.011 m^2
World X,Y,Z	0.00 m, 0.00 m, 0.00 m
Center of Mass	7.707E-08 m, 1.046E-08 m, 0.035 m
Bounding Box
    Length	0.043 m
    Width	0.043 m
    Height	0.10 m
Moment of Inertia at Center of Mass   (kg m^2)
    Ixx	6.920E-05
    Ixy	0.00
    Ixz	-1.447E-10
    Iyx	0.00
    Iyy	6.920E-05
    Iyz	0.00
    Izx	-1.447E-10
    Izy	0.00
    Izz	8.154E-06
Moment of Inertia at Origin   (kg m^2)
    Ixx	0.00
    Ixy	0.00
    Ixz	-3.180E-10
    Iyx	0.00
    Iyy	0.00
    Iyz	0.00
    Izx	-3.180E-10
    Izy	0.00
    Izz	8.154E-06
"""

rook_prop = """
Mass	0.061 kg
Volume	4.283E-05 m^3
Density	1425.00 kg / m^3
Area	0.01 m^2
World X,Y,Z	0.00 m, 0.00 m, 0.00 m
Center of Mass	-1.819E-06 m, -3.799E-07 m, 0.027 m
Bounding Box
    Length	0.041 m
    Width	0.041 m
    Height	0.069 m
Moment of Inertia at Center of Mass   (kg m^2)
    Ixx	3.107E-05
    Ixy	-6.476E-10
    Ixz	3.191E-09
    Iyx	-6.476E-10
    Iyy	3.107E-05
    Iyz	0.00
    Izx	3.191E-09
    Izy	0.00
    Izz	7.999E-06
Moment of Inertia at Origin   (kg m^2)
    Ixx	7.597E-05
    Ixy	-6.477E-10
    Ixz	6.203E-09
    Iyx	-6.477E-10
    Iyy	7.598E-05
    Iyz	5.710E-10
    Izx	6.203E-09
    Izy	5.710E-10
    Izz	7.999E-06
"""

board_prop = """
Mass	2.674 kg
Volume	0.005 m^3
Density	544.00 kg / m^3
Area	0.555 m^2
World X,Y,Z	0.00 m, 0.00 m, 0.00 m
Center of Mass	0.00 m, 0.00 m, -0.01 m
Bounding Box
    Length	0.508 m
    Width	0.508 m
    Height	0.019 m
Moment of Inertia at Center of Mass   (kg m^2)
    Ixx	0.058
    Ixy	0.00
    Ixz	0.00
    Iyx	0.00
    Iyy	0.058
    Iyz	0.00
    Izx	0.00
    Izy	0.00
    Izz	0.115
Moment of Inertia at Origin   (kg m^2)
    Ixx	0.058
    Ixy	0.00
    Ixz	0.00
    Iyx	0.00
    Iyy	0.058
    Iyz	0.00
    Izx	0.00
    Izy	0.00
    Izz	0.115
"""

# %%
# def createURDF(name, properties):
#     lines = []
#     lines.append(f'<robot name="{name}">\n')
#     lines.append(f'  <link name="piece_body">\n')


def make_parts(obj_filename, properties):
    section = 'General'  # General, BoundingBox, Inertia, NA
    MoI = {}
    CoM = None
    mass = None
    radius = 0
    sphere_radius = 0.001
    bb = {}
    for line in properties.split('\n'):
        if not line:
            continue
        if 'Bounding Box' in line:
            section = 'BoundingBox'
            continue
        if 'Moment of Inertia at Center of Mass' in line:
            section = 'Inertia'
            continue
        if 'Moment of Inertia at Origin' in line:
            section = 'NA'
            continue

        if section == 'General':
            values = line.split()
            if values[0] == 'Mass':
                mass = values[1]
                continue
            if 'Center of Mass' in line:
                CoM = [values[3], values[5], values[7]]
                continue
            continue

        if section == 'BoundingBox':
            values = line.split()
            bb[values[0]] = values[1]

        if section == 'Inertia':
            values = line.split()
            MoI[values[0]] = values[1]
    radius = max(float(bb['Length']), float(bb['Width'])) / 2

    # print(radius)
    # print(MoI)

    inertial = '<inertial>\n' \
    f'  <mass value="{mass}"/>\n' \
    f'  <origin xyz="{CoM[0]} {CoM[1]} {CoM[2]}" rpy="0 0 0"/>\n' \
    f'  <inertia ixx="{MoI["Ixx"]}" ixy="{MoI["Ixy"]}" ixz="{MoI["Ixz"]}" iyy="{MoI["Iyy"]}" iyz="{MoI["Iyz"]}" izz="{MoI["Izz"]}"/>\n' \
    '</inertial>\n'

    base_cylinder_height = 0.01
    collision = '<collision>\n' \
    f'  <origin rpy="0 0 0" xyz="0 0 {float(bb["Height"]) / 2}"/>\n' \
    f'  <geometry>\n' \
    f'    <cylinder radius="{radius * 0.8}" length="{bb["Height"]}"/>\n' \
    f'  </geometry>\n' \
    f'</collision>\n' \
    f'<collision>\n' \
    f'  <origin rpy="0 0 0" xyz="0 0 {base_cylinder_height / 2}"/>\n' \
    f'  <geometry>\n' \
    f'    <cylinder radius="{radius}" length="{base_cylinder_height}"/>\n' \
    f'  </geometry>\n' \
    '</collision>\n'

    contact_rad = radius * 0.8
    contact = [collision]
    for i in range(3):
        x = np.cos(2 * np.pi/3 * i)*contact_rad
        y = np.sin(2 * np.pi/3 * i)*contact_rad
        x = round(x, 3)
        y = round(y, 3)

        sphere_collision = '<collision>\n' \
        f'  <origin rpy="0 0 0" xyz="{x} {y} 0"/>\n' \
        f'  <geometry>\n' \
        f'    <sphere radius="{sphere_radius}"/>\n' \
        f'  </geometry>\n' \
        '</collision>\n'
        contact.append(sphere_collision)
    
    collision = ''.join(contact)

    visual = '<visual>\n' \
    f'  <origin rpy="0 0 0"/>\n' \
    f'  <geometry>\n' \
    f'    <mesh filename="{obj_filename}"/>\n' \
    f'  </geometry>\n' \
    f'</visual>\n'

    return inertial, collision, visual

def make_board_parts(obj_filename, properties):
    section = 'General'  # General, BoundingBox, Inertia, NA
    MoI = {}
    CoM = None
    mass = None
    radius = 0
    bb = {}
    for line in properties.split('\n'):
        if not line:
            continue
        if 'Bounding Box' in line:
            section = 'BoundingBox'
            continue
        if 'Moment of Inertia at Center of Mass' in line:
            section = 'Inertia'
            continue
        if 'Moment of Inertia at Origin' in line:
            section = 'NA'
            continue

        if section == 'General':
            values = line.split()
            if values[0] == 'Mass':
                mass = values[1]
                continue
            if 'Center of Mass' in line:
                CoM = [values[3], values[5], values[7]]
                continue
            continue

        if section == 'BoundingBox':
            values = line.split()
            bb[values[0]] = values[1]

        if section == 'Inertia':
            values = line.split()
            MoI[values[0]] = values[1]
    radius = max(float(bb['Length']), float(bb['Width'])) / 2

    # print(radius)
    # print(MoI)

    inertial = '<inertial>\n' \
    f'  <mass value="{mass}"/>\n' \
    f'  <origin xyz="{CoM[0]} {CoM[1]} {CoM[2]}" rpy="0 0 0"/>\n' \
    f'  <inertia ixx="{MoI["Ixx"]}" ixy="{MoI["Ixy"]}" ixz="{MoI["Ixz"]}" iyy="{MoI["Iyy"]}" iyz="{MoI["Iyz"]}" izz="{MoI["Izz"]}"/>\n' \
    '</inertial>\n'

    collision = '<collision>\n' \
    f'  <origin rpy="0 0 0" xyz="0 0 {-float(bb["Height"]) / 2}"/>\n' \
    '  <geometry>\n' \
    f'    <box size="{bb["Length"]} {bb["Width"]} {bb["Height"]}"/>\n' \
    f'  </geometry>\n' \
    '</collision>\n'

    visual = '<visual>\n' \
    f'  <origin rpy="0 0 0"/>\n' \
    f'  <geometry>\n' \
    f'    <mesh filename="{obj_filename}"/>\n' \
    f'  </geometry>\n' \
    f'</visual>\n'

    return inertial, collision, visual

def make_URDF(name, inertial, collision, visual, piece=True):
    lines = []
    lines.append(f'<?xml version="1.0" encoding="utf-8"?>')
    lines.append(f'<robot name="{name}">')
    if piece:
        lines.append(f'  <link name="piece_body">')
    else:
        lines.append(f'  <link name="board_body">')
    for subpart in [inertial, collision, visual]:
        for line in subpart.split('\n'):
            if line:
                lines.append('    ' + line)
    lines.append(f'  </link>')
    lines.append('</robot>')
    return '\n'.join(lines)

# %% [markdown]
# ## Generate all urdfs

# %%
prefixes = [
    'Bishop_B',
    'Bishop_W',

    'King_B',
    'King_W',

    'Knight_B',
    'Knight_W',

    'Pawn_B',
    'Pawn_W',

    'Queen_B',
    'Queen_W',

    'Rook_B',
    'Rook_W',
    ]

name_to_prop = {
    'Bishop_B': bishop_prop,
    'Bishop_W': bishop_prop,

    'King_B': king_prop,
    'King_W': king_prop,

    'Knight_B': knight_prop,
    'Knight_W': knight_prop,

    'Pawn_B': pawn_prop,
    'Pawn_W': pawn_prop,

    'Queen_B': queen_prop ,
    'Queen_W': queen_prop,

    'Rook_B': rook_prop,
    'Rook_W': rook_prop,
}

for prefix in prefixes:
    obj_filename = f'{prefix}.obj'
    obj_name = prefix
    obj_prop = name_to_prop[prefix] 
    urdf_fname = f'models/{prefix}.urdf'

    inertial, collision, visual = make_parts(obj_filename, obj_prop)
    urdf = make_URDF(obj_name, inertial, collision, visual)

    with open(urdf_fname, 'w') as f:
        f.write(urdf)

# %%
obj_filename = 'Bishop_W.obj'
obj_name = 'Bishop_W'
obj_prop = bishop_prop
urdf_fname = 'Bishop_W.urdf'

inertial, collision, visual = make_parts(obj_filename, obj_prop)
urdf = make_URDF(obj_name, inertial, collision, visual)

with open(urdf_fname, 'w') as f:
    f.write(urdf)
# print(urdf)

# %%
obj_filename = 'King_W.obj'
obj_name = 'King_W'
obj_prop = king_prop 
urdf_fname = 'King_W.urdf'

inertial, collision, visual = make_parts(obj_filename, obj_prop)
urdf = make_URDF(obj_name, inertial, collision, visual)

with open(urdf_fname, 'w') as f:
    f.write(urdf)
# print(urdf)

# %%
obj_filename = 'Knight_B.obj'
obj_name = 'knight_B'
obj_prop = knight_prop 
urdf_fname = 'Knight_B.urdf'

inertial, collision, visual = make_parts(obj_filename, obj_prop)
urdf = make_URDF(obj_name, inertial, collision, visual)

with open(urdf_fname, 'w') as f:
    f.write(urdf)

# %%
obj_filename = 'Pawn_W.obj'
obj_name = 'Pawn_W'
obj_prop = pawn_prop 
urdf_fname = 'Pawn_W.urdf'

inertial, collision, visual = make_parts(obj_filename, obj_prop)
urdf = make_URDF(obj_name, inertial, collision, visual)

with open(urdf_fname, 'w') as f:
    f.write(urdf)
# print(urdf)

# %%
obj_filename = 'Queen_W.obj'
obj_name = 'Queen_W'
obj_prop = queen_prop 
urdf_fname = 'Queen_W.urdf'

inertial, collision, visual = make_parts(obj_filename, obj_prop)
urdf = make_URDF(obj_name, inertial, collision, visual)

with open(urdf_fname, 'w') as f:
    f.write(urdf)

# %%
obj_filename = 'Rook_W.obj'
obj_name = 'Rook_W'
obj_prop = rook_prop 
urdf_fname = 'Rook_W.urdf'

inertial, collision, visual = make_parts(obj_filename, obj_prop)
urdf = make_URDF(obj_name, inertial, collision, visual)

with open(urdf_fname, 'w') as f:
    f.write(urdf)

# %%
obj_filename = 'simpleBoard.obj'
obj_name = 'Board'
obj_prop = board_prop 
urdf_fname = 'Board.urdf'

inertial, collision, visual = make_board_parts(obj_filename, obj_prop)
urdf = make_URDF(obj_name, inertial, collision, visual)

with open(urdf_fname, 'w') as f:
    f.write(urdf)
